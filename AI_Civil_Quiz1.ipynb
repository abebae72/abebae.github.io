# %% [markdown]
# <a href="https://colab.research.google.com/github/abebae72/abebae.github.io/blob/main/AI_Civil_Quiz1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-4, 16)
y = x**2-12*x

# %%
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y)
plt.show()
